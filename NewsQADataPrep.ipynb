# %% [markdown]
# This notebook converts the given NewsQA datasets into SQuAD format for evaluation

# %%
import numpy as np
import pandas as pd

# %%
train_file = pd.read_csv("train.csv")

# %%
train_file.head()
# Out:
#                                             story_id  \
# 0  ./cnn/stories/42d01e187213e86f5fe617fe32e716ff...
# 1  ./cnn/stories/c48228a52f26aca65c31fad273e66164...
# 2  ./cnn/stories/c65ed85800e4535f4bbbfa2c34d7d963...
# 3  ./cnn/stories/0cf66b646e9b32076513c050edf32a79...
# 4  ./cnn/stories/13012604e3203c18df09289dfedd14cd...
#
#                                           story_text  \
# 0  NEW DELHI , India -LRB- CNN -RRB- -- A high co...
# 1  -LRB- CNN -RRB- -- Fighting in the volatile Su...
# 2  Johannesburg -LRB- CNN -RRB- -- Miffed by a vi...
# 3  -LRB- CNN -RRB- -- England international footb...
# 4  BAGHDAD , Iraq -LRB- CNN -RRB- -- At least 6,0...
#
#                                             question answer_token_ranges
# 0         What was the amount of children murdered ?               60:61
# 1                    Where was one employee killed ?                8:12
# 2  who did say South Africa did not issue a visa ...               23:26
# 3           How many years old was the businessman ?               97:98
# 4                     What frightened the families ?             125:143

# %%
valid_file = pd.read_csv("dev.csv")
test_file = pd.read_csv("test.csv")

# %%
## Adding a unique ID column

train_file["id"] = train_file.index
train_file.head()
# Out:
#                                             story_id  \
# 0  ./cnn/stories/42d01e187213e86f5fe617fe32e716ff...
# 1  ./cnn/stories/c48228a52f26aca65c31fad273e66164...
# 2  ./cnn/stories/c65ed85800e4535f4bbbfa2c34d7d963...
# 3  ./cnn/stories/0cf66b646e9b32076513c050edf32a79...
# 4  ./cnn/stories/13012604e3203c18df09289dfedd14cd...
#
#                                           story_text  \
# 0  NEW DELHI , India -LRB- CNN -RRB- -- A high co...
# 1  -LRB- CNN -RRB- -- Fighting in the volatile Su...
# 2  Johannesburg -LRB- CNN -RRB- -- Miffed by a vi...
# 3  -LRB- CNN -RRB- -- England international footb...
# 4  BAGHDAD , Iraq -LRB- CNN -RRB- -- At least 6,0...
#
#                                             question answer_token_ranges  id
# 0         What was the amount of children murdered ?               60:61   0
# 1                    Where was one employee killed ?                8:12   1
# 2  who did say South Africa did not issue a visa ...               23:26   2
# 3           How many years old was the businessman ?               97:98   3
# 4                     What frightened the families ?             125:143   4

# %%
valid_file.head()
# Out:
#                                             story_id  \
# 0  ./cnn/stories/d191e20468fc7675fcfa55c33fab1e65...
# 1  ./cnn/stories/248826b18cd578159c43c5df340e9a30...
# 2  ./cnn/stories/1d77d0687a32e8147f87d0f97cb72242...
# 3  ./cnn/stories/00359f516cdf8b1800c7102711bd9aa4...
# 4  ./cnn/stories/7c0bda3744be6f7d95eef695e59a4e40...
#
#                                           story_text  \
# 0  TEHRAN , Iran -LRB- CNN -RRB- -- Iran 's parli...
# 1  LONDON , England -LRB- CNN -RRB- -- Israeli mi...
# 2  WASHINGTON -LRB- CNN -RRB- -- There are no imm...
# 3  LOS ANGELES , California -LRB- CNN -RRB- -- Fo...
# 4  -LRB- CNN -RRB- -- A Colorado prosecutor Frida...
#
#                                             question answer_token_ranges
# 0                              Iran criticizes who ?               13:17
# 1               What happened to the U.N. compound ?             590:595
# 2  Who said there is no immediate plans for deplo...               22:24
# 3               Will Lieberman investigate further ?             343:348
# 4                   Who spent nine years in prison ?               18:20

# %%
test_file.head()
# Out:
#                                             story_id  \
# 0  ./cnn/stories/289a45e715707cf650352f3eaa123f85...
# 1  ./cnn/stories/bce33bb5b5cff6b93065aa0cf91917c8...
# 2  ./cnn/stories/017df5c4fe1e79eb26957ff6a8b4c1e4...
# 3  ./cnn/stories/44f55c84c4a580853e384c860bb2ba3a...
# 4  ./cnn/stories/e117408ad19cc69e15b1e21b9ae54f10...
#
#                                           story_text  \
# 0  -LRB- CNN -RRB- -- Comcast rolled out a Web-ba...
# 1  -LRB- CNN -RRB- -- NASA wo n't have to maneuve...
# 2  -LRB- CNN -RRB- -- Decorating in the midst of ...
# 3  WASHINGTON -LRB- CNN -RRB- -- During the presi...
# 4  -LRB- CNN -RRB- -- The partnership started as ...
#
#                                             question answer_token_ranges
# 0                    What is going live on Tuesday ?                8:14
# 1  What was the space station crew forced to take...             302:306
# 2  for what People just do n't trust their instin...             652:671
# 3                           who is Sonia Sotomayor ?               29:30
# 4                Where did Lewis Partnership begin ?                4:22

# %%
## Applying to the dev and test sets

test_file["id"] = test_file.index
valid_file["id"] = valid_file.index

# %%
cols = train_file.columns.tolist()
cols = cols[-1:] + cols[:-1]
cols
# Out:
# ['id', 'story_id', 'story_text', 'question', 'answer_token_ranges']

# %%
train_file = train_file[cols]
train_file.head()
# Out:
#    id                                           story_id  \
# 0   0  ./cnn/stories/42d01e187213e86f5fe617fe32e716ff...
# 1   1  ./cnn/stories/c48228a52f26aca65c31fad273e66164...
# 2   2  ./cnn/stories/c65ed85800e4535f4bbbfa2c34d7d963...
# 3   3  ./cnn/stories/0cf66b646e9b32076513c050edf32a79...
# 4   4  ./cnn/stories/13012604e3203c18df09289dfedd14cd...
#
#                                           story_text  \
# 0  NEW DELHI , India -LRB- CNN -RRB- -- A high co...
# 1  -LRB- CNN -RRB- -- Fighting in the volatile Su...
# 2  Johannesburg -LRB- CNN -RRB- -- Miffed by a vi...
# 3  -LRB- CNN -RRB- -- England international footb...
# 4  BAGHDAD , Iraq -LRB- CNN -RRB- -- At least 6,0...
#
#                                             question answer_token_ranges
# 0         What was the amount of children murdered ?               60:61
# 1                    Where was one employee killed ?                8:12
# 2  who did say South Africa did not issue a visa ...               23:26
# 3           How many years old was the businessman ?               97:98
# 4                     What frightened the families ?             125:143

# %%
valid_file = valid_file[cols]
test_file = test_file[cols]
valid_file.head()
# Out:
#    id                                           story_id  \
# 0   0  ./cnn/stories/d191e20468fc7675fcfa55c33fab1e65...
# 1   1  ./cnn/stories/248826b18cd578159c43c5df340e9a30...
# 2   2  ./cnn/stories/1d77d0687a32e8147f87d0f97cb72242...
# 3   3  ./cnn/stories/00359f516cdf8b1800c7102711bd9aa4...
# 4   4  ./cnn/stories/7c0bda3744be6f7d95eef695e59a4e40...
#
#                                           story_text  \
# 0  TEHRAN , Iran -LRB- CNN -RRB- -- Iran 's parli...
# 1  LONDON , England -LRB- CNN -RRB- -- Israeli mi...
# 2  WASHINGTON -LRB- CNN -RRB- -- There are no imm...
# 3  LOS ANGELES , California -LRB- CNN -RRB- -- Fo...
# 4  -LRB- CNN -RRB- -- A Colorado prosecutor Frida...
#
#                                             question answer_token_ranges
# 0                              Iran criticizes who ?               13:17
# 1               What happened to the U.N. compound ?             590:595
# 2  Who said there is no immediate plans for deplo...               22:24
# 3               Will Lieberman investigate further ?             343:348
# 4                   Who spent nine years in prison ?               18:20

# %%
## Making the IDs for each entry unique and in string format

train_file["id"] = train_file["id"].astype(str)
train_file["id"] = train_file["id"] + "a"

valid_file["id"] = valid_file["id"].astype(str)
valid_file["id"] = valid_file["id"] + "b"

test_file["id"] = test_file["id"].astype(str)
test_file["id"] = test_file["id"] + "c"

train_file.head()
# Out:
#    id                                           story_id  \
# 0  0a  ./cnn/stories/42d01e187213e86f5fe617fe32e716ff...
# 1  1a  ./cnn/stories/c48228a52f26aca65c31fad273e66164...
# 2  2a  ./cnn/stories/c65ed85800e4535f4bbbfa2c34d7d963...
# 3  3a  ./cnn/stories/0cf66b646e9b32076513c050edf32a79...
# 4  4a  ./cnn/stories/13012604e3203c18df09289dfedd14cd...
#
#                                           story_text  \
# 0  NEW DELHI , India -LRB- CNN -RRB- -- A high co...
# 1  -LRB- CNN -RRB- -- Fighting in the volatile Su...
# 2  Johannesburg -LRB- CNN -RRB- -- Miffed by a vi...
# 3  -LRB- CNN -RRB- -- England international footb...
# 4  BAGHDAD , Iraq -LRB- CNN -RRB- -- At least 6,0...
#
#                                             question answer_token_ranges
# 0         What was the amount of children murdered ?               60:61
# 1                    Where was one employee killed ?                8:12
# 2  who did say South Africa did not issue a visa ...               23:26
# 3           How many years old was the businessman ?               97:98
# 4                     What frightened the families ?             125:143

# %%
train_file.to_csv("train.csv", index=False)
valid_file.to_csv("dev.csv", index=False)
test_file.to_csv("test.csv", index=False)

# %%
valid_file.head()
# Out:
#    id                                           story_id  \
# 0  0b  ./cnn/stories/d191e20468fc7675fcfa55c33fab1e65...
# 1  1b  ./cnn/stories/248826b18cd578159c43c5df340e9a30...
# 2  2b  ./cnn/stories/1d77d0687a32e8147f87d0f97cb72242...
# 3  3b  ./cnn/stories/00359f516cdf8b1800c7102711bd9aa4...
# 4  4b  ./cnn/stories/7c0bda3744be6f7d95eef695e59a4e40...
#
#                                           story_text  \
# 0  TEHRAN , Iran -LRB- CNN -RRB- -- Iran 's parli...
# 1  LONDON , England -LRB- CNN -RRB- -- Israeli mi...
# 2  WASHINGTON -LRB- CNN -RRB- -- There are no imm...
# 3  LOS ANGELES , California -LRB- CNN -RRB- -- Fo...
# 4  -LRB- CNN -RRB- -- A Colorado prosecutor Frida...
#
#                                             question answer_token_ranges
# 0                              Iran criticizes who ?               13:17
# 1               What happened to the U.N. compound ?             590:595
# 2  Who said there is no immediate plans for deplo...               22:24
# 3               Will Lieberman investigate further ?             343:348
# 4                   Who spent nine years in prison ?               18:20

# %%
test_string = "This is a test of the find method, disregard"
test_string.find("find method, disregard")
# Out:
# 22

# %%
train_file.answer_token_ranges.value_counts(dropna=False)
# Out:
# 4:6                585
# 7:9                530
# 4:5                380
# 8:10               361
# 6:8                340
#                   ...
# 299:307              1
# 351:352,365:366      1
# 1227:1234            1
# 228:253              1
# 948:955              1
# Name: answer_token_ranges, Length: 16810, dtype: int64

# %%
## Grabbing only the first range of answer
train_file["answer_token_lists"] =  train_file["answer_token_ranges"].str.split(",").apply(lambda x: x[0])

# %%
train_file.head()
# Out:
#    id                                           story_id  \
# 0  0a  ./cnn/stories/42d01e187213e86f5fe617fe32e716ff...
# 1  1a  ./cnn/stories/c48228a52f26aca65c31fad273e66164...
# 2  2a  ./cnn/stories/c65ed85800e4535f4bbbfa2c34d7d963...
# 3  3a  ./cnn/stories/0cf66b646e9b32076513c050edf32a79...
# 4  4a  ./cnn/stories/13012604e3203c18df09289dfedd14cd...
#
#                                           story_text  \
# 0  NEW DELHI , India -LRB- CNN -RRB- -- A high co...
# 1  -LRB- CNN -RRB- -- Fighting in the volatile Su...
# 2  Johannesburg -LRB- CNN -RRB- -- Miffed by a vi...
# 3  -LRB- CNN -RRB- -- England international footb...
# 4  BAGHDAD , Iraq -LRB- CNN -RRB- -- At least 6,0...
#
#                                             question answer_token_ranges  \
# 0         What was the amount of children murdered ?               60:61
# 1                    Where was one employee killed ?                8:12
# 2  who did say South Africa did not issue a visa ...               23:26
# 3           How many years old was the businessman ?               97:98
# 4                     What frightened the families ?             125:143
#
#   answer_token_lists
# 0              60:61
# 1               8:12
# 2              23:26
# 3              97:98
# 4            125:143

# %%
## Selecting the start and end indices of the answer

train_file["answer_token_start"] = train_file["answer_token_lists"].str.split(":").apply(lambda x: x[0]).astype(int)
train_file["answer_token_end"] = train_file["answer_token_lists"].str.split(":").apply(lambda x: x[1]).astype(int)

# %%
train_file.head()
# Out:
#    id                                           story_id  \
# 0  0a  ./cnn/stories/42d01e187213e86f5fe617fe32e716ff...
# 1  1a  ./cnn/stories/c48228a52f26aca65c31fad273e66164...
# 2  2a  ./cnn/stories/c65ed85800e4535f4bbbfa2c34d7d963...
# 3  3a  ./cnn/stories/0cf66b646e9b32076513c050edf32a79...
# 4  4a  ./cnn/stories/13012604e3203c18df09289dfedd14cd...
#
#                                           story_text  \
# 0  NEW DELHI , India -LRB- CNN -RRB- -- A high co...
# 1  -LRB- CNN -RRB- -- Fighting in the volatile Su...
# 2  Johannesburg -LRB- CNN -RRB- -- Miffed by a vi...
# 3  -LRB- CNN -RRB- -- England international footb...
# 4  BAGHDAD , Iraq -LRB- CNN -RRB- -- At least 6,0...
#
#                                             question answer_token_ranges  \
# 0         What was the amount of children murdered ?               60:61
# 1                    Where was one employee killed ?                8:12
# 2  who did say South Africa did not issue a visa ...               23:26
# 3           How many years old was the businessman ?               97:98
# 4                     What frightened the families ?             125:143
#
#   answer_token_lists  answer_token_start  answer_token_end
# 0              60:61                  60                61
# 1               8:12                   8                12
# 2              23:26                  23                26
# 3              97:98                  97                98
# 4            125:143                 125               143

# %%
## Getting the answer text

train_file["answer_text"] = train_file[["story_text", "answer_token_start", "answer_token_end"]].apply(
lambda row: " ".join(row["story_text"].split()[row["answer_token_start"]:row["answer_token_end"]]), axis=1)

# %%
train_file.head()
# Out:
#    id                                           story_id  \
# 0  0a  ./cnn/stories/42d01e187213e86f5fe617fe32e716ff...
# 1  1a  ./cnn/stories/c48228a52f26aca65c31fad273e66164...
# 2  2a  ./cnn/stories/c65ed85800e4535f4bbbfa2c34d7d963...
# 3  3a  ./cnn/stories/0cf66b646e9b32076513c050edf32a79...
# 4  4a  ./cnn/stories/13012604e3203c18df09289dfedd14cd...
#
#                                           story_text  \
# 0  NEW DELHI , India -LRB- CNN -RRB- -- A high co...
# 1  -LRB- CNN -RRB- -- Fighting in the volatile Su...
# 2  Johannesburg -LRB- CNN -RRB- -- Miffed by a vi...
# 3  -LRB- CNN -RRB- -- England international footb...
# 4  BAGHDAD , Iraq -LRB- CNN -RRB- -- At least 6,0...
#
#                                             question answer_token_ranges  \
# 0         What was the amount of children murdered ?               60:61
# 1                    Where was one employee killed ?                8:12
# 2  who did say South Africa did not issue a visa ...               23:26
# 3           How many years old was the businessman ?               97:98
# 4                     What frightened the families ?             125:143
#
#   answer_token_lists  answer_token_start  answer_token_end  \
# 0              60:61                  60                61
# 1               8:12                   8                12
# 2              23:26                  23                26
# 3              97:98                  97                98
# 4            125:143                 125               143
#
#                                          answer_text
# 0                                                 19
# 1                          Sudanese region of Darfur
# 2                            Archbishop Desmond Tutu
# 3                                        29-year-old
# 4  a series of killings and threats by Muslim ext...

# %%
## Getting the start character of the answer in the story text

train_file["answer_start_char"] = train_file[["story_text", "answer_text"]].apply(
lambda row: row["story_text"].find(row["answer_text"]), axis=1)

# %%
train_file.head()
# Out:
#    id                                           story_id  \
# 0  0a  ./cnn/stories/42d01e187213e86f5fe617fe32e716ff...
# 1  1a  ./cnn/stories/c48228a52f26aca65c31fad273e66164...
# 2  2a  ./cnn/stories/c65ed85800e4535f4bbbfa2c34d7d963...
# 3  3a  ./cnn/stories/0cf66b646e9b32076513c050edf32a79...
# 4  4a  ./cnn/stories/13012604e3203c18df09289dfedd14cd...
#
#                                           story_text  \
# 0  NEW DELHI , India -LRB- CNN -RRB- -- A high co...
# 1  -LRB- CNN -RRB- -- Fighting in the volatile Su...
# 2  Johannesburg -LRB- CNN -RRB- -- Miffed by a vi...
# 3  -LRB- CNN -RRB- -- England international footb...
# 4  BAGHDAD , Iraq -LRB- CNN -RRB- -- At least 6,0...
#
#                                             question answer_token_ranges  \
# 0         What was the amount of children murdered ?               60:61
# 1                    Where was one employee killed ?                8:12
# 2  who did say South Africa did not issue a visa ...               23:26
# 3           How many years old was the businessman ?               97:98
# 4                     What frightened the families ?             125:143
#
#   answer_token_lists  answer_token_start  answer_token_end  \
# 0              60:61                  60                61
# 1               8:12                   8                12
# 2              23:26                  23                26
# 3              97:98                  97                98
# 4            125:143                 125               143
#
#                                          answer_text  answer_start_char
# 0                                                 19                305
# 1                          Sudanese region of Darfur                 44
# 2                            Archbishop Desmond Tutu                114
# 3                                        29-year-old                540
# 4  a series of killings and threats by Muslim ext...                697

# %%
## Putting the answer text and answer start char in dictionary format (as in SQuAD)

train_file["answers"] = train_file[["answer_text", "answer_start_char"]].apply(
lambda row: {"text": [row["answer_text"]], "answer_start": [row["answer_start_char"]]}, axis=1)

# %%
train_file.head()
# Out:
#    id                                           story_id  \
# 0  0a  ./cnn/stories/42d01e187213e86f5fe617fe32e716ff...
# 1  1a  ./cnn/stories/c48228a52f26aca65c31fad273e66164...
# 2  2a  ./cnn/stories/c65ed85800e4535f4bbbfa2c34d7d963...
# 3  3a  ./cnn/stories/0cf66b646e9b32076513c050edf32a79...
# 4  4a  ./cnn/stories/13012604e3203c18df09289dfedd14cd...
#
#                                           story_text  \
# 0  NEW DELHI , India -LRB- CNN -RRB- -- A high co...
# 1  -LRB- CNN -RRB- -- Fighting in the volatile Su...
# 2  Johannesburg -LRB- CNN -RRB- -- Miffed by a vi...
# 3  -LRB- CNN -RRB- -- England international footb...
# 4  BAGHDAD , Iraq -LRB- CNN -RRB- -- At least 6,0...
#
#                                             question answer_token_ranges  \
# 0         What was the amount of children murdered ?               60:61
# 1                    Where was one employee killed ?                8:12
# 2  who did say South Africa did not issue a visa ...               23:26
# 3           How many years old was the businessman ?               97:98
# 4                     What frightened the families ?             125:143
#
#   answer_token_lists  answer_token_start  answer_token_end  \
# 0              60:61                  60                61
# 1               8:12                   8                12
# 2              23:26                  23                26
# 3              97:98                  97                98
# 4            125:143                 125               143
#
#                                          answer_text  answer_start_char  \
# 0                                                 19                305
# 1                          Sudanese region of Darfur                 44
# 2                            Archbishop Desmond Tutu                114
# 3                                        29-year-old                540
# 4  a series of killings and threats by Muslim ext...                697
#
#                                              answers
# 0            {'text': ['19'], 'answer_start': [305]}
# 1  {'text': ['Sudanese region of Darfur'], 'answe...
# 2  {'text': ['Archbishop Desmond Tutu'], 'answer_...
# 3   {'text': ['29-year-old'], 'answer_start': [540]}
# 4  {'text': ['a series of killings and threats by...

# %%
## Applying these same transformations to the dev and test sets

valid_file["answer_token_lists"] =  valid_file["answer_token_ranges"].str.split(",").apply(lambda x: x[0])
valid_file["answer_token_start"] = valid_file["answer_token_lists"].str.split(":").apply(lambda x: x[0]).astype(int)
valid_file["answer_token_end"] = valid_file["answer_token_lists"].str.split(":").apply(lambda x: x[1]).astype(int)
valid_file["answer_text"] = valid_file[["story_text", "answer_token_start", "answer_token_end"]].apply(
lambda row: " ".join(row["story_text"].split()[row["answer_token_start"]:row["answer_token_end"]]), axis=1)
valid_file["answer_start_char"] = valid_file[["story_text", "answer_text"]].apply(
lambda row: row["story_text"].find(row["answer_text"]), axis=1)
valid_file["answers"] = valid_file[["answer_text", "answer_start_char"]].apply(
lambda row: {"text": [row["answer_text"]], "answer_start": [row["answer_start_char"]]}, axis=1)

test_file["answer_token_lists"] =  test_file["answer_token_ranges"].str.split(",").apply(lambda x: x[0])
test_file["answer_token_start"] = test_file["answer_token_lists"].str.split(":").apply(lambda x: x[0]).astype(int)
test_file["answer_token_end"] = test_file["answer_token_lists"].str.split(":").apply(lambda x: x[1]).astype(int)
test_file["answer_text"] = test_file[["story_text", "answer_token_start", "answer_token_end"]].apply(
lambda row: " ".join(row["story_text"].split()[row["answer_token_start"]:row["answer_token_end"]]), axis=1)
test_file["answer_start_char"] = test_file[["story_text", "answer_text"]].apply(
lambda row: row["story_text"].find(row["answer_text"]), axis=1)
test_file["answers"] = test_file[["answer_text", "answer_start_char"]].apply(
lambda row: {"text": [row["answer_text"]], "answer_start": [row["answer_start_char"]]}, axis=1)

# %%
valid_file.head()
# Out:
#    id                                           story_id  \
# 0  0b  ./cnn/stories/d191e20468fc7675fcfa55c33fab1e65...
# 1  1b  ./cnn/stories/248826b18cd578159c43c5df340e9a30...
# 2  2b  ./cnn/stories/1d77d0687a32e8147f87d0f97cb72242...
# 3  3b  ./cnn/stories/00359f516cdf8b1800c7102711bd9aa4...
# 4  4b  ./cnn/stories/7c0bda3744be6f7d95eef695e59a4e40...
#
#                                           story_text  \
# 0  TEHRAN , Iran -LRB- CNN -RRB- -- Iran 's parli...
# 1  LONDON , England -LRB- CNN -RRB- -- Israeli mi...
# 2  WASHINGTON -LRB- CNN -RRB- -- There are no imm...
# 3  LOS ANGELES , California -LRB- CNN -RRB- -- Fo...
# 4  -LRB- CNN -RRB- -- A Colorado prosecutor Frida...
#
#                                             question answer_token_ranges  \
# 0                              Iran criticizes who ?               13:17
# 1               What happened to the U.N. compound ?             590:595
# 2  Who said there is no immediate plans for deplo...               22:24
# 3               Will Lieberman investigate further ?             343:348
# 4                   Who spent nine years in prison ?               18:20
#
#   answer_token_lists  answer_token_start  answer_token_end  \
# 0              13:17                  13                17
# 1            590:595                 590               595
# 2              22:24                  22                24
# 3            343:348                 343               348
# 4              18:20                  18                20
#
#                          answer_text  answer_start_char  \
# 0  U.S. President-elect Barack Obama                 75
# 1                hit and set on fire               3246
# 2                    President Obama                122
# 3          intends to follow up with               1980
# 4                        Tim Masters                112
#
#                                              answers
# 0  {'text': ['U.S. President-elect Barack Obama']...
# 1  {'text': ['hit and set on fire'], 'answer_star...
# 2  {'text': ['President Obama'], 'answer_start': ...
# 3  {'text': ['intends to follow up with'], 'answe...
# 4   {'text': ['Tim Masters'], 'answer_start': [112]}

# %%
## dropping added preprocessing columns
dead_cols = ["answer_token_lists", "answer_token_start", "answer_token_end", "answer_text", "answer_start_char"]

train_file.drop(dead_cols, axis=1, inplace=True)
valid_file.drop(dead_cols, axis=1, inplace=True)
test_file.drop(dead_cols, axis=1, inplace=True)

# %%
train_file.head()
# Out:
#    id                                           story_id  \
# 0  0a  ./cnn/stories/42d01e187213e86f5fe617fe32e716ff...
# 1  1a  ./cnn/stories/c48228a52f26aca65c31fad273e66164...
# 2  2a  ./cnn/stories/c65ed85800e4535f4bbbfa2c34d7d963...
# 3  3a  ./cnn/stories/0cf66b646e9b32076513c050edf32a79...
# 4  4a  ./cnn/stories/13012604e3203c18df09289dfedd14cd...
#
#                                           story_text  \
# 0  NEW DELHI , India -LRB- CNN -RRB- -- A high co...
# 1  -LRB- CNN -RRB- -- Fighting in the volatile Su...
# 2  Johannesburg -LRB- CNN -RRB- -- Miffed by a vi...
# 3  -LRB- CNN -RRB- -- England international footb...
# 4  BAGHDAD , Iraq -LRB- CNN -RRB- -- At least 6,0...
#
#                                             question answer_token_ranges  \
# 0         What was the amount of children murdered ?               60:61
# 1                    Where was one employee killed ?                8:12
# 2  who did say South Africa did not issue a visa ...               23:26
# 3           How many years old was the businessman ?               97:98
# 4                     What frightened the families ?             125:143
#
#                                              answers
# 0            {'text': ['19'], 'answer_start': [305]}
# 1  {'text': ['Sudanese region of Darfur'], 'answe...
# 2  {'text': ['Archbishop Desmond Tutu'], 'answer_...
# 3   {'text': ['29-year-old'], 'answer_start': [540]}
# 4  {'text': ['a series of killings and threats by...

# %%
train_file.to_csv("train.csv", index=False)
valid_file.to_csv("dev.csv", index=False)
test_file.to_csv("test.csv", index=False)
