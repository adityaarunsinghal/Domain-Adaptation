# %%
import pandas as pd
import json

# %%
f = open("data/data_for_inspection(scp-ed)/squad.film.test.json")
filmQA = json.load(f)['data']

# %%
f = open("data/data_for_inspection(scp-ed)/squad_dev-v2.0.json")
squad = json.load(f)['data']

# %%
filmQA
# Out:
# rt': 25, 'text': '$22 Million'}],
#       'question': 'what is tom selleck worth',
#       'id': '856513_0'}]}]},
#  {'paragraphs': [{'context': 'Thor, the lightning-wielding superhero played by the Chris Hemsworth in the Marvel movies, will be recast as a female in new comic book series that will launch in October. “We’re really excited about this; it’s definitely shaking things up,” Marvel Comics editor-in-chief Axel Alonso told the Daily News.',
#     'qas': [{'answers': [{'answer_start': 53, 'text': 'Chris Hemsworth'}],
#       'question': 'who plays thor in marvel',
#       'id': '1048798_7'}]}]},
#  {'paragraphs': [{'context': 'Wolverine 3: Who is X-23 in Logan? Marvel Comics fans are all too familiar with the name X-23, aka Laura Kinney. However, movie fans who are just now watching the trailer for Logan (aka Wolverine 3) have seen that the film revolves around a mysterious girl - one who is a lot like Wolverine.',
# ...

# %%
squad
# Out:
# 'rotational', 'answer_start': 242}],
#       'question': "What inertia exists because of Newton's Fourth Law of Motion?",
#       'id': '5ad28846d7d075001a42992e',
#       'answers': [],
#       'is_impossible': True},
#      {'plausible_answers': [{'text': 'angular', 'answer_start': 113}],
#       'question': 'What equation is torque like regarding velocity?',
#       'id': '5ad28846d7d075001a42992f',
#       'answers': [],
#       'is_impossible': True},
#      {'plausible_answers': [{'text': 'Torque', 'answer_start': 0}],
#       'question': 'What is the rotational equivalent of velocity?',
#       'id': '5ad28846d7d075001a429930',
#       'answers': [],
#       'is_impossible': True},
#      {'plausible_answers': [{'text': 'First Law of Motion',
#         'answer_start': 208}],
#       'question': "Which of Newton's Laws described a rotational inertia equation?",
#       'id': '5ad28846d7d075001a429931',
#       'answers': [],
#       'is_impossible': True}],
# ...

# %%
pd.DataFrame(filmQA[0]['paragraphs'][0])
# Out:
#                                              context  \
# 0  The Sea of Monsters received good reviews and ...
#
#                                                  qas
# 0  {'answers': [{'answer_start': 168, 'text': '10...

# %%
pd.DataFrame(filmQA['data']['paragraphs'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-844c79131c62> in <module>
# ----> 1 pd.DataFrame(filmQA['data']['paragraphs'])
#
# TypeError: list indices must be integers or slices, not str

# %%
pd.read_json(filmQA)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-4dc6e9177762> in <module>
# ----> 1 pd.read_json(filmQA)
#
# ~/Documents/GitHub/Domain-Adaptation/domain_venv/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     197                 else:
#     198                     kwargs[new_arg_name] = new_arg_value
# --> 199             return func(*args, **kwargs)
#     200
#     201         return cast(F, wrapper)
#
# ~/Documents/GitHub/Domain-Adaptation/domain_venv/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     297                 )
#     298                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 299             return func(*args, **kwargs)
#     300
#     301         return wrapper
#
# ...
